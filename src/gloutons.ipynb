# %%
import socket
def scan_ports(host):
    open_ports = []
    for port in range(1, 1025):
        s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        socket.setdefaulttimeout(0.5)
        result = s.connect_ex((host, port))
        if result == 0:
            open_ports.append(port)
        s.close()
    return open_ports
target = "127.0.0.1"
ports = scan_ports(target)
print("Open ports on", target, ":", ports)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 13
#      11     return open_ports
#      12 target = "127.0.0.1"
# ---> 13 ports = scan_ports(target)
#      14 print("Open ports on", target, ":", ports)
#
# Cell In[1], line 7, in scan_ports(host)
#       5 s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
#       6 socket.setdefaulttimeout(0.5)
# ----> 7 result = s.connect_ex((host, port))
#       8 if result == 0:
#       9     open_ports.append(port)
#
# KeyboardInterrupt:
